# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [raw]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [raw]
# ## Problem Statement

# %% [markdown]
# I work for a school district that has asked me to advise their high school students on what SAT score they should be aiming for based on their intended area of study or school preferences.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ## Describe datasets selected
# 1. sat_2019_by_intended_college_major.csv: 2019 SAT Scores by Intended College Major
# 2. at_act_by_college.csv: Ranges of Accepted ACT & SAT Student Scores by Colleges

# %%
# Import and view 2019 SAT scores by college major
sat_scores_by_major = pd.read_csv('../data/sat_2019_by_intended_college_major.csv')
sat_scores_by_major.head(10)
# Out:
#                                 IntendedCollegeMajor TestTakers Percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                  Architecture and Related Services     28,988      2%
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                 Biological and Biomedical Sciences    155,834      8%
# 4  Business, Management, Marketing, and Related S...    221,523     12%
# 5    Communication, Journalism, and Related Programs     36,332      2%
# 6  Computer and Information Sciences and Support ...     79,736      4%
# 7                       Construction Trades, General      2,500      0%
# 8                                          Education     71,882      4%
# 9                                        Engineering    194,127     11%
#
#    Total  ReadingWriting  Math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# ...

# %%
# What is the shape of the data

sat_scores_by_major.describe()
# Out:
#              Total  ReadingWriting        Math
# count    38.000000       38.000000   38.000000
# mean   1058.500000      535.500000  523.000000
# std      82.445969       41.362439   43.386385
# min     916.000000      458.000000  456.000000
# 25%     988.250000      501.250000  486.500000
# 50%    1066.500000      537.000000  527.000000
# 75%    1115.500000      569.750000  542.250000
# max    1242.000000      597.000000  646.000000

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# manual mean calculation

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Manually calculate the standard deviation:

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
test_optional = pd.read_csv('../data/sat_act_by_college.csv')
test_optional.head()
# Out:
#                  School Test Optional? Applies to Class Year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
# 3   Columbia University            Yes                     2021
# 4       Yale University            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile
# ...

# %%
# Check for missing values
test_optional.describe()
# Out:
#        Number of Applicants
# count            416.000000
# mean           17481.759615
# std            17447.621897
# min              211.000000
# 25%             5313.000000
# 50%            11622.000000
# 75%            23599.750000
# max           111322.000000

# %%
# Check for missing values - Accept Rate
test_optional['Accept Rate'].describe()
# Out:
# count       416
# unique      314
# top       57.9%
# freq          4
# Name: Accept Rate, dtype: object

# %%
# Check for missing values - SAT Total 25th-75th Percentile
test_optional['SAT Total 25th-75th Percentile'].describe()
# Out:
# count           416
# unique          286
# top       1070-1270
# freq              6
# Name: SAT Total 25th-75th Percentile, dtype: object

# %%
#check to see if column is needed
test_optional['test_optional?'].describe()
# Out:
# count     416
# unique      5
# top       Yes
# freq      347
# Name: test_optional?, dtype: object

# %%
# Look for dtypes of the columns
test_optional.dtypes
# Out:
# School                            object
# Test Optional?                    object
# Applies to Class Year(s)          object
# Policy Details                    object
# Number of Applicants               int64
# Accept Rate                       object
# SAT Total 25th-75th Percentile    object
# ACT Total 25th-75th Percentile    object
# dtype: object

# %%
# Fix any incorrect data types found in step 5 (source: Rowan Schaefer)
test_optional['Accept Rate'] = test_optional['Accept Rate'].str.replace("%","").astype(float)

# %%
# Double check Accept Rate is now a float
test_optional.dtypes
# Out:
# School                             object
# Test Optional?                     object
# Applies to Class Year(s)           object
# Policy Details                     object
# Number of Applicants                int64
# Accept Rate                       float64
# SAT Total 25th-75th Percentile     object
# ACT Total 25th-75th Percentile     object
# dtype: object

# %%
# Rename Columns: Should be lowercase and contain no space
test_optional.columns = test_optional.columns.str.lower().str.replace(" ", "_")

# %%
test_optional.columns
# Out:
# Index(['school', 'test_optional?', 'applies_to_class_year(s)',
#        'policy_details', 'number_of_applicants', 'accept_rate',
#        'sat_total_25th-75th_percentile', 'act_total_25th-75th_percentile',
#        'sat_25th', 'sat_75th'],
#       dtype='object')

# %%
test_optional = test_optional[test_optional['sat_total_25th-75th_percentile'] != '--']

# %%
# create two columns for SAT 25th and 75th percentile (# Received help from Katie Sylvia)
test_optional[['sat_25th', 'sat_75th']] = test_optional['sat_total_25th-75th_percentile'].str.split('-', 1, expand=True)

# %%
#Received help from Katie Sylvia (remove space and indentation)
test_optional['sat_25th'] = test_optional['sat_25th'].str.strip().str.strip('\u200b\u200b')

# %%
#Received help from Katie Sylvia
test_optional['sat_75th'] = test_optional['sat_75th'].str.strip().str.strip('\u200b\u200b')

# %%
pd.set_option("display.max_rows", None)

# %%
test_optional['sat_25th'].value_counts()
# Out:
# 1070      20
# 1160      15
# 1150      15
# 1130      13
# 1120      13
# 1080      13
# 1050      12
# 1180      12
# 990       12
# 1040      11
# 1140      11
# 1110      11
# 1100      11
# 1220      10
# 1240      10
# 1060      10
# 1030      10
# 1090       9
# 1200       9
# 1210       9
# 1010       9
# 1300       8
# 1190       8
# 1280       8
# 1170       8
# 1250       7
# 1370       6
# 1230       6
# 1330       6
# 1020       5
# 1440       5
# 1000       5
# 1360       5
# 1260       5
# 1340       5
# 1270       5
# 1320       5
# 1350       4
# 1290       4
# 1450       4
# 1460       4
# 1310       4
# 1390       3
# 1380       2
# 1078       2
# 940        2
# 910        2
# 1490       2
# 950        2
# 980        2
# 1470       2
# 1400       2
# 1410       2
# 960        2
# 970        1
# 1143       1
# 1275       1
# 793        1
# 1108       1
# 1012       1
# 1153       1
# 1245       1
# 1038       1
# 1008       1
# 890        1
# 1248       1
# ...

# %%
test_optional['sat_75th'].value_counts()
# Out:
# 1320    21
# 1310    17
# 1360    15
# 1250    15
# 1340    14
# 1260    14
# 1350    13
# 1270    13
# 1440    12
# 1290    12
# 1370    12
# 1380    11
# 1420    11
# 1510    10
# 1410    10
# 1230     9
# 1300     9
# 1390     9
# 1570     9
# 1480     9
# 1520     9
# 1560     9
# 1330     8
# 1460     8
# 1240     8
# 1530     8
# 1280     7
# 1210     7
# 1400     7
# 1490     7
# 1450     7
# 1500     6
# 1540     6
# 1430     6
# 1180     5
# 1220     5
# 1200     5
# 1190     5
# 1470     5
# 1550     4
# 1130     3
# 1170     2
# 1358     2
# 1345     2
# 1160     2
# 1213     2
# 1368     1
# 1080     1
# 1078     1
# 1465     1
# 1285     1
# 1398     1
# 1140     1
# 1365     1
# 1273     1
# 1269     1
# 1225     1
# 1485     1
# 1265     1
# 1295     1
# 1090     1
# 1338     1
# 1150     1
# 1580     1
# 1205     1
# 1050     1
# Name: sat_75th, dtype: int64

# %%
test_optional['sat_25th'] = test_optional['sat_25th'].astype(float)
test_optional['sat_75th'] = test_optional['sat_75th'].astype(float)

# %%
# Drop ACT column permamently since the problem statement is focused on SAT scores
test_optional = test_optional.drop(columns=['act_total_25th-75th_percentile'])

# %%
test_optional.head()
# Out:
#                  school test_optional? applies_to_class_year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
# 3   Columbia University            Yes                     2021
# 4       Yale University            Yes                     2021
#
#                                       policy_details  number_of_applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
# 3  Columbia has adopted a one-year test optional ...                 40203
# 4  Yale has adopted a one-year test optional poli...                 36844
#
#    accept_rate sat_total_25th-75th_percentile  sat_25th  sat_75th
# ...

# %%
# Count of value frequency
test_optional['test_optional?'].value_counts()
# Out:
# Yes         347
# No           26
# Yes (TB)     25
# Yes*         16
# Yes (TF)      2
# Name: test_optional?, dtype: int64

# %%
# Count of value frequency
test_optional['sat_total_25th-75th_percentile'].value_counts()
# Out:
# 1070-1270    6
# --           6
# 1120-1320    5
# 1140-1320    5
# 1150-1360    4
#             ..
# 910-1130     1
# 1060-1320    1
# 1090-1270    1
# 1190-1440    1
# 820-1050     1
# Name: sat_total_25th-75th_percentile, Length: 286, dtype: int64

# %%
# Count of value frequency (applies to class years)
test_optional['applies_to_class_year(s)'].value_counts()
# Out:
# 2021                        196
# All / Permanent Policy      158
# 2021 2022 2023               15
# 2021 2022                    11
# 2021 2022 2023 2024           9
# 2021 2022 2023 2024 2025      1
# Name: applies_to_class_year(s), dtype: int64

# %%
# Count of value frequency (policy details)
test_optional['policy_details'].value_counts()
# Out:
# The Cal State system has adopted a one-year test blind policy meaning they will not consider standardized test scores for applicants to the 2020-21 admission cycle.                                                                                                                                                                                                                   15
# The UC system has adopted a two-year test optional policy for first-year applicants both domestic and international beginning in the 2020-21 admission cycle. After those two years the UCs will be Test Blind (meaning they will not consider test scores) for two more years. At the end of the four year period they will consider whether to reinstate the testing requirement.     6
# ...

# %%
test_optional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 410 entries, 0 to 415
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   school                          410 non-null    object
#  1   test_optional?                  410 non-null    object
#  2   applies_to_class_year(s)        385 non-null    object
#  3   policy_details                  410 non-null    object
#  4   number_of_applicants            410 non-null    int64
#  5   accept_rate                     410 non-null    float64
#  6   sat_total_25th-75th_percentile  410 non-null    object
#  7   sat_25th                        410 non-null    float64
#  8   sat_75th                        410 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 32.0+ KB

# %%
test_optional.isna()
# Out:
#      school  test_optional?  applies_to_class_year(s)  policy_details  \
# 0     False           False                     False           False
# 1     False           False                     False           False
# 2     False           False                     False           False
# 3     False           False                     False           False
# 4     False           False                     False           False
# 5     False           False                     False           False
# 6     False           False                     False           False
# 7     False           False                     False           False
# 8     False           False                     False           False
# 9     False           False                     False           False
# 10    False           False                     False           False
# 11    False           False                     False           False
# ...

# %%
test_optional.dropna()
# Out:
#                                                 school test_optional?  \
# 0                                  Stanford University            Yes
# 1                                      Harvard College            Yes
# 2                                 Princeton University            Yes
# 3                                  Columbia University            Yes
# 4                                      Yale University            Yes
# 5                   California Institute of Technology       Yes (TB)
# 6                Massachusetts Institute of Technology            Yes
# 7                                     Brown University            Yes
# 8                                University of Chicago            Yes
# 9                                       Pomona College            Yes
# 10                          University of Pennsylvania            Yes
# 11                                   Dartmouth College            Yes
# ...

# %%
# Check the last 5 rows in data set
test_optional.tail()
# Out:
#                                     school test_optional?  \
# 411  University of Texas Rio Grande Valley             No
# 412             University of South Dakota             No
# 413              University of Mississippi             No
# 414                  University of Wyoming             No
# 415            University of Texas El Paso             No
#
#     applies_to_class_year(s)  \
# 411                      NaN
# 412                      NaN
# 413                      NaN
# 414                      NaN
# 415                      NaN
#
#                                         policy_details  number_of_applicants  \
# 411  University of Texas Rio Grande Valley requires...                 10680
# 412  Unviersity of South Dakota requires either the...                  4434
# 413  Ole Miss requires either the SAT or ACT. It do...                 15371
# 414  University of Wyoming requires either the SAT ...                  5348
# ...

# %%
# Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
sat_scores_by_major = pd.read_csv('../data/sat_2019_by_intended_college_major.csv')
sat_scores_by_major.head()
# Out:
#                                 IntendedCollegeMajor TestTakers Percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1%
# 1                  Architecture and Related Services     28,988      2%
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0%
# 3                 Biological and Biomedical Sciences    155,834      8%
# 4  Business, Management, Marketing, and Related S...    221,523     12%
#
#    Total  ReadingWriting  Math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# 4   1072             534   537

# %%
# Check for missing values
sat_scores_by_major.describe()
# Out:
#              Total  ReadingWriting        Math
# count    38.000000       38.000000   38.000000
# mean   1058.500000      535.500000  523.000000
# std      82.445969       41.362439   43.386385
# min     916.000000      458.000000  456.000000
# 25%     988.250000      501.250000  486.500000
# 50%    1066.500000      537.000000  527.000000
# 75%    1115.500000      569.750000  542.250000
# max    1242.000000      597.000000  646.000000

# %%
sat_scores_by_major.tail()
# Out:
#                    IntendedCollegeMajor TestTakers Percent  Total  \
# 33     Theology and Religious Vocations      1,991      0%   1096
# 34  Transportation and Materials Moving      1,105      0%   1019
# 35  Visual and Performing Arts, General    130,642      7%   1045
# 36                                Other     26,888      1%    963
# 37                            Undecided    126,939      7%   1069
#
#     ReadingWriting  Math
# 33             561   535
# 34             511   508
# 35             536   510
# 36             488   476
# 37             538   532

# %%
# Check for missing values - Accept Rate
sat_scores_by_major['IntendedCollegeMajor'].describe()
# Out:
# count                                                    38
# unique                                                   38
# top       Agriculture, AgricultureOperations, and Relate...
# freq                                                      1
# Name: IntendedCollegeMajor, dtype: object

# %%
sat_scores_by_major.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   IntendedCollegeMajor  38 non-null     object
#  1   TestTakers            38 non-null     object
#  2   Percent               38 non-null     float64
#  3   Total                 38 non-null     int64
#  4   ReadingWriting        38 non-null     int64
#  5   Math                  38 non-null     int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 1.9+ KB

# %%
# Rename Columns: Should be lowercase and contain no space
sat_scores_by_major.columns = sat_scores_by_major.columns.str.lower()

# %%
sat_scores_by_major.head()
# Out:
#                                 intendedcollegemajor testtakers  percent  \
# 0  Agriculture, AgricultureOperations, and Relate...     24,913      1.0
# 1                  Architecture and Related Services     28,988      2.0
# 2         Area, Ethnic, Cultural, and Gender Studies      2,629      0.0
# 3                 Biological and Biomedical Sciences    155,834      8.0
# 4  Business, Management, Marketing, and Related S...    221,523     12.0
#
#    total  readingwriting  math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# 4   1072             534   537

# %%
# Fix any incorrect data types found in step 5 (source: Rowan Schaefer)
sat_scores_by_major["percent"]= sat_scores_by_major["percent"].astype(float)

# %%
# Fix any incorrect data types found in step 5
sat_scores_by_major["testtakers"]= sat_scores_by_major["testtakers"].str.replace(",", "").astype(int)

# %%
sat_scores_by_major.head()
# Out:
#                                 intendedcollegemajor  testtakers  percent  \
# 0  Agriculture, AgricultureOperations, and Relate...       24913      1.0
# 1                  Architecture and Related Services       28988      2.0
# 2         Area, Ethnic, Cultural, and Gender Studies        2629      0.0
# 3                 Biological and Biomedical Sciences      155834      8.0
# 4  Business, Management, Marketing, and Related S...      221523     12.0
#
#    total  readingwriting  math
# 0    977             496   481
# 1   1047             520   527
# 2   1040             536   504
# 3   1139             572   566
# 4   1072             534   537

# %%
sat_scores_by_major.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   intendedcollegemajor  38 non-null     object
#  1   testtakers            38 non-null     int32
#  2   percent               38 non-null     float64
#  3   total                 38 non-null     int64
#  4   readingwriting        38 non-null     int64
#  5   math                  38 non-null     int64
# dtypes: float64(1), int32(1), int64(3), object(1)
# memory usage: 1.8+ KB

# %%
# Count of value frequency - Test Takers
sat_scores_by_major['testtakers'].value_counts()
# Out:
# 24913     1
# 319       1
# 7448      1
# 2979      1
# 10147     1
# 13039     1
# 6668      1
# 3381      1
# 26318     1
# 75626     1
# 28988     1
# 7852      1
# 68177     1
# 33356     1
# 1991      1
# 1105      1
# 130642    1
# 26888     1
# 6592      1
# 16508     1
# 283       1
# 8611      1
# 2629      1
# 155834    1
# 221523    1
# 36332     1
# 79736     1
# 2500      1
# 71882     1
# 194127    1
# 33595     1
# 16233     1
# 6469      1
# 9936      1
# 331026    1
# 12611     1
# 35788     1
# 126939    1
# Name: testtakers, dtype: int64

# %%
# Count of value frequency - Total
sat_scores_by_major['total'].value_counts()
# Out:
# 1139    2
# 1069    2
# 1104    2
# 977     1
# 932     1
# 1155    1
# 960     1
# 929     1
# 1120    1
# 1203    1
# 1001    1
# 1064    1
# 916     1
# 975     1
# 1164    1
# 1096    1
# 1019    1
# 1045    1
# 984     1
# 1105    1
# 1242    1
# 1047    1
# 1140    1
# 1090    1
# 1048    1
# 1102    1
# 953     1
# 1119    1
# 1041    1
# 1022    1
# 919     1
# 1156    1
# 1072    1
# 1040    1
# 963     1
# Name: total, dtype: int64

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Code: Standard Deviation

# %%
# Code: Mean

# %%
# Sort values by Accept Rate
test_optional.sort_values(by= 'accept_rate', ascending=[True])
# Out:
#                                                 school test_optional?  \
# 0                                  Stanford University            Yes
# 1                                      Harvard College            Yes
# 2                                 Princeton University            Yes
# 3                                  Columbia University            Yes
# 4                                      Yale University            Yes
# 5                   California Institute of Technology       Yes (TB)
# 6                Massachusetts Institute of Technology            Yes
# 7                                     Brown University            Yes
# 8                                University of Chicago            Yes
# 9                                       Pomona College            Yes
# 10                          University of Pennsylvania            Yes
# 11                                   Dartmouth College            Yes
# ...

# %%
# Sort values by SAT 25th Percentile
test_optional.sort_values(by= 'sat_25th', ascending=[False])
# Out:
#                                                 school test_optional?  \
# 5                   California Institute of Technology       Yes (TB)
# 6                Massachusetts Institute of Technology            Yes
# 31                                 Harvey Mudd College            Yes
# 8                                University of Chicago            Yes
# 35                  Washington University in St. Louis            Yes
# 18                            Johns Hopkins University            Yes
# 1                                      Harvard College            Yes
# 37                          Carnegie Mellon University            Yes
# 4                                      Yale University            Yes
# 16                               Vanderbilt University            Yes
# 13                                     Duke University            Yes
# 20                                     Rice University            Yes
# ...

# %%
# What is the mean SAT scores by Intended College Major
sat_scores_by_major.groupby('intendedcollegemajor')['total'].mean()
# Out:
# intendedcollegemajor
# Agriculture, AgricultureOperations, and Related Sciences          977.0
# Architecture and Related Services                                1047.0
# Area, Ethnic, Cultural, and Gender Studies                       1040.0
# Biological and Biomedical Sciences                               1139.0
# Business, Management, Marketing, and Related Support Services    1072.0
# Communication, Journalism, and Related Programs                  1069.0
# Computer and Information Sciences and Support Services           1156.0
# Construction Trades, General                                      919.0
# Education                                                        1022.0
# Engineering                                                      1139.0
# Engineering Technologies/Technicians                             1041.0
# English Language and Literature/Letters                          1119.0
# Family and Consumer Sciences/Human Sciences                       953.0
# ...

# %%
# Sort values by Total SAT scores
top_10_college_majors = sat_scores_by_major.sort_values(by= 'total', ascending=[False])[:10]

top_10_college_majors
# Out:
#                                  intendedcollegemajor  testtakers  percent  \
# 19                         Mathematics and Statistics       16508      1.0
# 27                                  Physical Sciences       26318      1.0
# 32                                    Social Sciences       33356      2.0
# 6   Computer and Information Sciences and Support ...       79736      4.0
# 22                    Multi/Interdisciplinary Studies        2979      0.0
# 17  Liberal Arts and Sciences, General Studies and...        8611      0.0
# 3                  Biological and Biomedical Sciences      155834      8.0
# 9                                         Engineering      194127     11.0
# 26                   Philosophy and Religious Studies        3381      0.0
# 11            English Language and Literature/Letters       16233      1.0
#
#     total  readingwriting  math
# 19   1242             597   646
# 27   1203             597   606
# 32   1164             594   570
# ...

# %%
# plt.barh
# Size
plt.figure(figsize = (10, 5))
plt.title('Ranking of Top 10 College Majors by Total SAT Score')
plt.xlabel('Combined SAT Score');
plt.savefig("MajorsRanking by Total SAT")


plt.barh(top_10_college_majors['intendedcollegemajor'][:: -1],top_10_college_majors['total'][:: -1], color = 'darkred');

# %%
# Sort values by Math SAT scores (College majors ranked by math SAT scores)
top_10_math_score = sat_scores_by_major.sort_values(by= 'math', ascending=[False])[:10]

top_10_math_score
# Out:
#                                  intendedcollegemajor  testtakers  percent  \
# 19                         Mathematics and Statistics       16508      1.0
# 27                                  Physical Sciences       26318      1.0
# 6   Computer and Information Sciences and Support ...       79736      4.0
# 9                                         Engineering      194127     11.0
# 22                    Multi/Interdisciplinary Studies        2979      0.0
# 32                                    Social Sciences       33356      2.0
# 3                  Biological and Biomedical Sciences      155834      8.0
# 17  Liberal Arts and Sciences, General Studies and...        8611      0.0
# 26                   Philosophy and Religious Studies        3381      0.0
# 23                 Natural resources and Conservation       10147      1.0
#
#     total  readingwriting  math
# 19   1242             597   646
# 27   1203             597   606
# 6    1156             571   585
# ...

# %%
# plt.barh (based on Math Scores)
# Size
plt.figure(figsize = (10, 5))
plt.title('Ranking of Top 10 College Majors by Math SAT Score')
plt.xlabel('Math SAT Score');
plt.savefig("MajorsRanking by Math SAT")


plt.barh(top_10_math_score['intendedcollegemajor'][:: -1],top_10_math_score['math'][:: -1], color = 'purple');

# %%
# Sort values by ReadingWriting SAT scores (College majors ranked by Reading/Writing SAT scores)
top_10_reading_score = sat_scores_by_major.sort_values(by= 'readingwriting', ascending=[False])[:10]

top_10_reading_score
# Out:
#                                  intendedcollegemajor  testtakers  percent  \
# 19                         Mathematics and Statistics       16508      1.0
# 27                                  Physical Sciences       26318      1.0
# 32                                    Social Sciences       33356      2.0
# 11            English Language and Literature/Letters       16233      1.0
# 17  Liberal Arts and Sciences, General Studies and...        8611      0.0
# 22                    Multi/Interdisciplinary Studies        2979      0.0
# 18                      Library Science/Librarianship         283      0.0
# 3                  Biological and Biomedical Sciences      155834      8.0
# 26                   Philosophy and Religious Studies        3381      0.0
# 6   Computer and Information Sciences and Support ...       79736      4.0
#
#     total  readingwriting  math
# 19   1242             597   646
# 27   1203             597   606
# 32   1164             594   570
# ...

# %%
# plt.barh (based on Math Scores)
# Size
plt.figure(figsize = (10, 5))
plt.title('Ranking of Top 10 College Majors by Reading/Writing SAT Score')
plt.xlabel('Reading/Writing SAT Score');
plt.savefig("MajorsRanking by Reading SAT")


plt.barh(top_10_reading_score['intendedcollegemajor'][:: -1],top_10_reading_score['readingwriting'][:: -1]);

# %%
# What is the mean SAT(25th percentile) scores by school
grouped = test_optional.groupby('school')['sat_25th'].mean()

#grouped.sort_values(by= 'sat_25th', ascending=[False])
top_10_schools = grouped.sort_values(ascending=False)[:10]

# %%
top_10_schools
# Out:
# school
# California Institute of Technology       1530.0
# Massachusetts Institute of Technology    1500.0
# University of Chicago                    1490.0
# Harvey Mudd College                      1490.0
# Washington University in St. Louis       1470.0
# Johns Hopkins University                 1470.0
# Carnegie Mellon University               1460.0
# Yale University                          1460.0
# Vanderbilt University                    1460.0
# Harvard College                          1460.0
# Name: sat_25th, dtype: float64

# %%
fig, ax=plt.subplots(figsize=(10,5))
sns.barplot(y = top_10_schools.index, x= top_10_schools.values, orient='h', ax=ax)
ax.set_xlabel('SAT Scores 25th Percentile')
ax.set_ylabel('School', size=12)
ax.set_title('SAT Scores Required by Top 10 Schools (25th Percentile)');
for i in ax.containers:
    ax.bar_label(i,)  # Coding help by Tanveer Khan
plt.savefig('SATScores25th')

# %%
# What is the mean SAT(75th percentile) scores by school
grouped_75th = test_optional.groupby('school')['sat_75th'].mean()

#grouped.sort_values(by= 'sat_75th', ascending=[False])
top_schools_75th = grouped_75th.sort_values(ascending=False)[:10]

# %%
fig, ax=plt.subplots(figsize=(10,5))
sns.barplot(y = top_schools_75th.index, x= top_schools_75th.values, orient='h',ax=ax);
ax.set_xlabel('SAT Scores 75th Percentile')
ax.set_ylabel('School', size=12)
ax.set_title('SAT Scores of Enrolled Students by Top 10 Schools (75th Percentile)');
for i in ax.containers: # Coding help by Tanveer Khan
    ax.bar_label(i,)
plt.savefig('SATScores75th')

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#Heatmap for Corrrelation
plt.figure(figsize=(10,10))
sns.heatmap(sat_scores_by_major.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# Boxplot of total SAT 
sns.boxplot(x = sat_scores_by_major.total);

# %%
# Boxplot of total SAT 
sns.boxplot(x = test_optional['accept_rate']);

# %%
plt.scatter(test_optional['accept_rate'], test_optional['sat_25th'])
plt.xlabel('College Acceptance Rate')
plt.ylabel('Total SAT Score - 25th Percentile', size=11)
plt.title('Correlation of Acceptance Rate with SAT Scores in 25th Percentile')
plt.savefig('AcceptRate_25thPercentile.jpeg')

# %%
plt.figure(figsize=(10,5)) #Received codimg help from Rowan Schafer
plt.scatter(test_optional['accept_rate'], test_optional['sat_75th'], color = 'darkred', alpha=0.5)
plt.xlabel('College Acceptance Rate%')
plt.ylabel('Total SAT Score - 75th Percentile')
plt.title('College Acceptance Rate by SAT Scores in 75th Percentile')
plt.xticks(np.arange(0,101, step=10))
plt.savefig('AcceptRate_75thPercentile.jpeg')

# %%
test_10=test_optional[test_optional['accept_rate']<10]

plt.scatter(test_10['accept_rate'], test_10['sat_75th'], color = 'darkred');
plt.xlabel('College Acceptance Rate%')
plt.ylabel('Total SAT Score - 75th Percentile')
plt.title('Acceptance Rate <10% with SAT Scores in 75th Percentile')
# #plt.savefig('AcceptRate_75thPercentile.jpeg')
# Out:
# Text(0.5, 1.0, 'Acceptance Rate <10% with SAT Scores in 75th Percentile')

# %%
test_10
# Out:
#                                     school test_optional?  \
# 0                      Stanford University            Yes
# 1                          Harvard College            Yes
# 2                     Princeton University            Yes
# 3                      Columbia University            Yes
# 4                          Yale University            Yes
# 5       California Institute of Technology       Yes (TB)
# 6    Massachusetts Institute of Technology            Yes
# 7                         Brown University            Yes
# 8                    University of Chicago            Yes
# 9                           Pomona College            Yes
# 10              University of Pennsylvania            Yes
# 11                       Dartmouth College            Yes
# 12                         Bowdoin College            Yes
# 13                         Duke University            Yes
# 14                      Swarthmore College            Yes
# ...

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*
#
# Gaining enrollment in the nation’s top universities and colleges is extremely competitive
# Students with the intention to major in mathematics, sciences and engineering earned the highest scores on both the math and reading/writing sections
# Recommendations for Greenburgh School District
# Identify Target Schools based on SAT score ranges (25%-75th Percentile)
# Build a plan for college readiness including strong emphasis on math and science
# Build an SAT Prep Plan to increase student success on the test
